# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('Mobile.csv')

# %%
df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
df.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for column in df.columns:
    print("Unique columns:",column)
    print(df[column].unique())
    print()
# Out:
# Unique columns: battery_power
# [ 842 1021  563 ... 1139 1467  858]
#
# Unique columns: blue
# [0 1]
#
# Unique columns: clock_speed
# [2.2 0.5 2.5 1.2 1.7 0.6 2.9 2.8 2.1 1.  0.9 1.1 2.6 1.4 1.6 2.7 1.3 2.3
#  2.  1.8 3.  1.5 1.9 2.4 0.8 0.7]
#
# Unique columns: dual_sim
# [0 1]
#
# Unique columns: fc
# [ 1  0  2 13  3  4  5  7 11 12 16  6 15  8  9 10 18 17 14 19]
#
# Unique columns: four_g
# [0 1]
#
# Unique columns: int_memory
# [ 7 53 41 10 44 22 24  9 33 17 52 46 13 23 49 19 39 47 38  8 57 51 21  5
#  60 61  6 11 50 34 20 27 42 40 64 14 63 43 16 48 12 55 36 30 45 29 58 25
#   3 54 15 37 31 32  4 18  2 56 26 35 59 28 62]
#
# Unique columns: m_dep
# [0.6 0.7 0.9 0.8 0.1 0.5 1.  0.3 0.4 0.2]
#
# Unique columns: mobile_wt
# [188 136 145 131 141 164 139 187 174  93 182 177 159 198 185 196 121 101
#   81 156 199 114 111 132 143  96 200  88 150 107 100 157 160 119  87 152
#  166 110 118 162 127 109 102 104 148 180 128 134 144 168 155 165  80 138
# ...

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['battery_power'], kde=True, color='purple', bins=30)
plt.title('Distribution of Battery Power')
plt.xlabel('Battery Power (mAh)')
plt.ylabel('Count')
plt.show()

# %% [raw]
# Histogram with KDE – Battery Power Distribution
# Battery power shows a right-skewed distribution indicating most mobiles have moderate battery levels.
# This is a histogram with KDE showing frequency distribution and smooth density.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='four_g', y='ram', data=df)
plt.title('RAM vs. 4G Capability')
plt.xlabel('4G Support (0=No, 1=Yes)')
plt.ylabel('RAM')
plt.show()

# %% [raw]
# Boxplot – RAM vs 4G Capability
# Phones with 4G support generally have higher RAM compared to those without 4G.
# This is a boxplot comparing RAM distribution across 4G categories.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='clock_speed', y='battery_power', hue='dual_sim', data=df)
plt.title('Clock Speed vs. Battery Power (Dual SIM Colored)')
plt.xlabel('Clock Speed (GHz)')
plt.ylabel('Battery Power')
plt.legend(title='Dual SIM')
plt.show()

# %% [raw]
# Scatter Plot – Clock Speed vs Battery Power (Dual SIM)
# Phones with dual SIM support are spread across all clock speeds and battery levels.
# This is a scatter plot colored by the dual_sim feature.

# %%
plt.figure(figsize=(8, 6))
pivot = df.pivot_table(index='sc_h', columns='sc_w', values='battery_power', aggfunc='mean')
sns.heatmap(pivot, cmap='YlGnBu')
plt.title('Average Battery Power by Screen Height and Width')
plt.xlabel('Screen Width')
plt.ylabel('Screen Height')
plt.show()

# %% [raw]
# Heatmap – Screen Height vs Width vs Battery Power
# Battery power tends to increase with larger screen height and width combinations.
# This is a heatmap showing average battery power across screen dimensions.

# %%
plt.figure(figsize=(14, 10))
corr = df.corr()
sns.heatmap(corr, annot=False, cmap='coolwarm', linewidths=0.5)
plt.title('Feature Correlation Heatmap')
plt.show()

# %% [raw]
# Correlation Heatmap – All Features
# RAM and battery power show strong positive correlation while some features are weakly related.
# This is a correlation heatmap visualizing pairwise relationships between numerical features.

# %%
df['pixel_density'] = df['px_height'] * df['px_width']
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='ram', y='pixel_density', hue='touch_screen')
plt.title('RAM vs. Pixel Density Colored by Touchscreen')
plt.xlabel('RAM')
plt.ylabel('Pixel Density')
plt.show()

# %% [raw]
# Scatter Plot – RAM vs Pixel Density (Touchscreen)
# Touchscreen phones generally have higher RAM and pixel density than non-touchscreen ones.
# This is a scatter plot comparing RAM and pixel density colored by touchscreen support.

# %% [markdown]
# # Pivot Tables

# %%
pivot1 = df.pivot_table(values='ram', index='four_g', columns='dual_sim', aggfunc='mean')
print(pivot1)
# Out:
# dual_sim            0            1
# four_g
# 0         2040.764331  2188.781893
# 1         2113.960784  2148.889306

# %% [raw]
# Phones that support both 4G and dual SIM tend to have higher average RAM.

# %%
pivot2 = df.pivot_table(values='battery_power', index='touch_screen', columns='wifi', aggfunc='mean')
print(pivot2)
# Out:
# wifi                    0            1
# touch_screen
# 0             1241.719758  1244.606426
# 1             1242.757143  1225.540698

# %% [raw]
# Touchscreen phones with WiFi have the highest average battery power.

# %%
pivot3 = df.pivot_table(values='mobile_wt', index='int_memory', columns='three_g', aggfunc='mean')
print(pivot3)
# Out:
# three_g              0           1
# int_memory
# 2           131.090909  140.451613
# 3           112.750000  146.619048
# 4           168.333333  123.705882
# 5           133.000000  147.222222
# 6           148.571429  145.800000
# ...                ...         ...
# 60          132.000000  154.608696
# 61          123.000000  130.736842
# 62          134.250000  137.000000
# 63          135.363636  131.315789
# 64          125.375000  150.956522
#
# [63 rows x 2 columns]

# %% [raw]
# Mobiles with higher internal memory and 3G support tend to be heavier.

# %%
pivot4 = df.pivot_table(values=['px_height', 'px_width'], index='fc', aggfunc='mean')
print(pivot4)
# Out:
#       px_height     px_width
# fc
# 0    664.137131  1261.314346
# 1    646.779592  1246.971429
# 2    631.460317  1241.460317
# 3    633.217647  1228.270588
# 4    657.654135  1285.180451
# 5    614.438849  1260.633094
# 6    664.910714  1267.401786
# 7    643.090000  1258.890000
# 8    683.675325  1241.753247
# 9    580.384615  1253.961538
# 10   603.532258  1145.596774
# 11   661.078431  1233.901961
# 12   629.355556  1276.822222
# 13   591.000000  1133.275000
# 14   561.450000  1397.750000
# 15   637.304348  1326.652174
# 16   610.375000  1200.541667
# 17  1112.166667  1632.666667
# 18   880.454545  1294.181818
# 19   405.000000   742.000000

# %% [raw]
# As front camera megapixels increase, average screen resolution also increases.

# %%
df['target'] = pd.qcut(df['ram'], q=4, labels=[0, 1, 2, 3])

# %%
X = df.drop(columns='target')
y = df['target'].astype(int)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, classification_report

# %%
imputer =SimpleImputer(strategy='mean')
X_imputed = imputer.fit_transform(X)

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_imputed)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred_knn = knn.predict(X_test)
print("\nKN Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KN Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.72      0.72       105
#            1       0.36      0.48      0.41        81
#            2       0.59      0.53      0.56       109
#            3       0.86      0.72      0.79       105
#
#     accuracy                           0.62       400
#    macro avg       0.63      0.62      0.62       400
# weighted avg       0.65      0.62      0.63       400

# %% [markdown]
# # Gaussian NB

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)
print("\nGaussian NB Classification Report:\n", classification_report(y_test, y_pred_gnb))
# Out:
# Gaussian NB Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       105
#            1       0.81      0.85      0.83        81
#            2       0.93      0.89      0.91       109
#            3       0.97      0.96      0.97       105
#
#     accuracy                           0.91       400
#    macro avg       0.91      0.91      0.91       400
# weighted avg       0.91      0.91      0.91       400

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logr = LogisticRegression(max_iter=1000)
logr.fit(X_train, y_train)
y_pred_logr = logr.predict(X_test)
print("\nLogistic Regression Classification Report:\n", classification_report(y_test, y_pred_logr))
# Out:
# Logistic Regression Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.94      0.96       105
#            1       0.85      0.98      0.91        81
#            2       0.97      0.90      0.93       109
#            3       0.97      0.97      0.97       105
#
#     accuracy                           0.94       400
#    macro avg       0.94      0.95      0.94       400
# weighted avg       0.95      0.94      0.95       400

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svm = SVC()
svm.fit(X_train, y_train)
y_pred_svm = svm.predict(X_test)
print("\nSVM Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91       105
#            1       0.77      0.83      0.80        81
#            2       0.90      0.80      0.84       109
#            3       0.92      0.92      0.92       105
#
#     accuracy                           0.87       400
#    macro avg       0.87      0.87      0.87       400
# weighted avg       0.87      0.87      0.87       400

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
y_pred_dt = dt.predict(X_test)
print("\nDecision Tree Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       1.00      1.00      1.00        81
#            2       1.00      1.00      1.00       109
#            3       1.00      1.00      1.00       105
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# # Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)
print("\nRandom Forest Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       0.99      1.00      0.99        81
#            2       1.00      0.99      1.00       109
#            3       1.00      1.00      1.00       105
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# # Ada Boost

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(X_train, y_train)
y_pred_ada = ada.predict(X_test)
print("\nAdaBoost Classification Report:\n", classification_report(y_test, y_pred_ada))
# Out:
# AdaBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       1.00      1.00      1.00        81
#            2       1.00      1.00      1.00       109
#            3       1.00      1.00      1.00       105
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# # Gradient Boost

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb = GradientBoostingClassifier()
gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)
print("\nGradient Boosting Classification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       1.00      1.00      1.00        81
#            2       1.00      1.00      1.00       109
#            3       1.00      1.00      1.00       105
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# # XG Boost

# %%
from xgboost import XGBClassifier
xb =XGBClassifier()
xb.fit(X_train, y_train)
y_pred_gb = xb.predict(X_test)
print("\nGradient Boosting Classification Report:\n", classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       105
#            1       1.00      1.00      1.00        81
#            2       1.00      1.00      1.00       109
#            3       1.00      1.00      1.00       105
#
#     accuracy                           1.00       400
#    macro avg       1.00      1.00      1.00       400
# weighted avg       1.00      1.00      1.00       400

# %% [markdown]
# # Observation

# %%
models = ['KNN', 'GNB', 'LR', 'SVM', 'DT', 'RF', 'AB', 'XG', 'GradientBoosting']
accuracies = [0.62,0.91,0.94,0.87,1.00,1.00,1.00,1.00,1.00]
plt.figure(figsize=(10, 6))
plt.plot(models, accuracies, marker='o', linestyle='-', color='b')
plt.title('Model Accuracies')
plt.xlabel('Models')
plt.ylabel('Accuracy (%)')
plt.grid(True)
plt.show()

# %% [raw]
# The line graph shows model accuracies where DecisionTree, XGBoost, and GradientBoosting achieved perfect accuracy, RandomForest performed nearly perfectly, LogisticRegression and GaussianNB showed strong results, while KNN performed the lowest.
